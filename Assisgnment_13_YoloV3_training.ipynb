# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathbolla/EVA5/blob/S13/Assisgnment_13_YoloV3_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Cloned the repository

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 46.44 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %% [markdown]
# ### Uploaded the Custom Dataset

# %%
#gdrive/My\ Drive/Colab\ Notebooks/EVA5/S12_Assignment
# !unzip -qq '/content/gdrive/My Drive/Colab Notebooks/EVA5/S13_Assignment/YoloV3_dataset.zip'

# %%
# !mv YoloV3_dataset/ YoloV3/data/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %% [markdown]
# #### Training for 30 Epochs

# %%
# !python train.py --data data/YoloV3_dataset/custom.data --batch 16 --cache --cfg cfg/yolov3-custom1.cfg --epochs 30 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom1.cfg', data='data/YoloV3_dataset/custom.data', device='', epochs=30, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-26 13:23:30.449526: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [00:00<00:00, 8278.73it/s]
# Caching images (1.8GB): 100% 3203/3203 [00:19<00:00, 167.11it/s]
# ...

# %%
# !mkdir new_imgs

# %% [markdown]
# ### For inference on Video, collecting frames from a video using FFMPEG

# %%
# !ffmpeg -i '/content/hat-boot-mask-vest.mp4' -vf fps=24 new_imgs/img%03d.jpg
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %% [markdown]
# #### Detecting on all the individual images using the latest saved model & saving them.

# %%
# !python detect.py --cfg 'cfg/yolov3-custom1.cfg' --names 'data/YoloV3_dataset/custom.names' --source 'new_imgs' --conf-thres 0.1 --output new_out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom1.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/YoloV3_dataset/custom.names', output='new_out_out', save_txt=False, source='new_imgs', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/1652 new_imgs/img001.jpg: 320x512 2 vests, Done. (0.033s)
# image 2/1652 new_imgs/img002.jpg: 320x512 2 vests, Done. (0.033s)
# image 3/1652 new_imgs/img003.jpg: 320x512 2 vests, Done. (0.028s)
# image 4/1652 new_imgs/img004.jpg: 320x512 2 vests, Done. (0.022s)
# image 5/1652 new_imgs/img005.jpg: 320x512 2 vests, Done. (0.022s)
# image 6/1652 new_imgs/img006.jpg: 320x512 2 vests, Done. (0.022s)
# image 7/1652 new_imgs/img007.jpg: 320x512 Done. (0.022s)
# ...

# %% [markdown]
# #### Used FFMPEG to convert all the output images to make video again

# %%
# !ffmpeg -framerate 30 -i 'new_out_out/img%03d.jpg' Yolov3_hat_boot_mask_vest.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
